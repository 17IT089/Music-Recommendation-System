# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = "/content/drive/My Drive/Music Recommendation/song_data.csv"

# %%
song_data = pd.read_csv(path,usecols=['user_id','song_id','listen_count','title','artist','song'],dtype={'user_id':'str','song_id':'str','listen_count':'int32','title':'str','artist':'str','song':'str'})
song_data.head(10)
# Out:
#                                     user_id  ...                                 song
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...             The Cove By Jack Johnson
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...     Entre Dos Aguas By Paco De Lucia
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...               Stronger By Kanye West
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...       Constellations By Jack Johnson
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...         Learn To Fly By Foo Fighters
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...           Paper Gangsta By Lady GaGa
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...       Stacked Actors By Foo Fighters
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...            Sehr kosmisch By Harmonia
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...                Clarity By John Mayer
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e  ...  The Old Saloon By The Lonely Island
#
# [10 rows x 6 columns]

# %%
song_data = song_data[['song','listen_count']]
song_data
# Out:
#                                              song  listen_count
# 0                        The Cove By Jack Johnson             1
# 1                Entre Dos Aguas By Paco De Lucia             2
# 2                          Stronger By Kanye West             1
# 3                  Constellations By Jack Johnson             1
# 4                    Learn To Fly By Foo Fighters             1
# ...                                           ...           ...
# 607674                     Girls And Boys By Blur             1
# 607675                 Imma Be By Black Eyed Peas             1
# 607676                  Sehr kosmisch By Harmonia             4
# 607677            Fireflies By Charttraxx Karaoke             3
# 607678  Every Planet We Reach Is Dead By Gorillaz             1
#
# [607679 rows x 2 columns]

# %%
song_data = song_data.groupby('song').sum()
song_data.sort_values(by=['listen_count'], inplace=True, ascending=False)
song_data = song_data.reset_index() 
song_data.head(10)
# Out:
#                               song  listen_count
# 0         Revelry By Kings Of Leon         21278
# 1        Sehr kosmisch By Harmonia         15813
# 2           Secrets By OneRepublic         11524
# 3       Canada By Five Iron Frenzy         11099
# 4              Invalid By Tub Ring         10569
# 5  Fireflies By Charttraxx Karaoke          7626
# 6              Tive Sim By Cartola          7410
# 7  The Gift By Angels and Airwaves          7035
# 8                Marry Me By Train          6710
# 9    Use Somebody By Kings Of Leon          5710

# %%
# function to recommend new songs
def Music_Recommendation(song_name, k):

  # to convert dataframe into array
  song_list = (song_data['song']).to_list() 

  # to check if song selected by user is available?
  if song_name in song_list :

    print("Song "+"'"+song_name+"'"+" is available")
    song_index = (song_list.index(song_name))

    # total listen count of the song which is selected by user
    song_listen_count = (song_data['listen_count'].iloc[song_index])
    new_distance_list = []

    for i in range(len(song_data)):
      if i != song_index :

        # calculate euclidean distance
        abs_distance = abs(song_listen_count - song_data['listen_count'][i])
        new_distance_list.append([abs_distance,song_data['song'][i]])

    # to sort distance list by ascending order     
    new_distance_list = sorted(new_distance_list)

    print("Top " + str(k) + " Recommendation for you.......")
    for i in range(k):
      print(i+1,")",new_distance_list[i][1])
    
      
  else:
     print("Song "+"'"+song_name+"'"+" is not available")
     print("Top " + str(k) + " Recommendation for you.......")
     recommend_song = song_data[['song']].head(k)
     for i in range(k):
      print(i+1,")",recommend_song['song'][i])

k = 10
Music_Recommendation('Trahison By Vitalic', k)
# Out:
# Song 'Trahison By Vitalic' is available
# Top 10 Recommendation for you.......
# 1 ) Slan Le Maige By Reel Feelings
# 2 ) Kill The King By Megadeth
# 3 ) Bodies Hit The Floor By Girl Talk
# 4 ) A Face In The Crowd By Tom Petty
# 5 ) Mystic Brew By Ronnie Foster
# 6 ) Southern State By Bright Eyes
# 7 ) Cold Gin By Kiss
# 8 ) Phone Call From The Moon By Adrian Belew
# 9 ) Sing By Four Tet
# 10 ) Time to Go By Dropkick Murphys
